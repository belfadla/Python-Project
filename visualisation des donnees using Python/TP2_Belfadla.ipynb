# %% [markdown]
# # TP 2
# réaliser par : BELFADLA FATIMA EZZAHRA

# %%
import numpy as np 
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv("Caffeine.csv",encoding='utf-8')
data.head(100)
# Out:
#                                  drink      Volume  Calories  Caffeine    type
# 0                         Costa Coffee  256.993715         0       277  Coffee
# 1          Coffee Friend Brewed Coffee  250.191810         0       145  Coffee
# 2                   Hell Energy Coffee  250.191810       150       100  Coffee
# 3                   Killer Coffee (AU)  250.191810         0       430  Coffee
# 4                         Nescafe Gold  250.191810         0        66  Coffee
# ..                                 ...         ...       ...       ...     ...
# 95            High Voltage Coffee (AU)  354.882000         0      1150  Coffee
# 96   International Delight Iced Coffee  354.882000       180        88  Coffee
# 97        Seattle's Best Brewed Coffee  354.882000        10       260  Coffee
# 98    Starbucks Iced Espresso Classics  354.882000       190       125  Coffee
# 99  Stipe Miocic Extra Strength Coffee  354.882000         0       500  Coffee
#
# [100 rows x 5 columns]

# %%
data.boxplot()
# Out:
# <AxesSubplot:>

# %%
data.boxplot(column = "Caffeine",by = "type")
plt.title('caffeine')
plt.show()

# %%
sns.boxplot(x = "Volume", y= "Caffeine", hue="type", data=data);

# %%
sns.boxplot(x = "Caffeine" , hue="type", data=data);
